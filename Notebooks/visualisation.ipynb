# %%
import matplotlib.pyplot as plt
import folium as fm
import table_evaluator as te
import pandas as pd

# %%
def plot_map(data):
    map_center = [data['latitude'].mean(), data['longitude'].mean()]
    map = fm.Map(location=map_center, zoom_start=12)

    for _, row in data.iterrows():
        fm.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=1,
        color='blue',
        fill=True,
        fill_color='blue'
    ).add_to(map)
    return map

# %%
def plot_evaluation(real, fake, cat=None, target=None):
    table = te.TableEvaluator(real, fake, cat)

    if target:
        table.evaluate(target_col=target)
    
    table.visual_evaluation()
    return

# %%
data = pd.read_csv('/workspaces/Synthetic-Data-Generation/Data/Real/dataset_gps.csv')
map = plot_map(data)

plot_evaluation(data, data, cat=None, target=None)
